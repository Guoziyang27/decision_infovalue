# %%
import pandas as pd

# %%
rl_qwen8b = pd.read_csv("data_compl_signal/cxr_foundations_w_thinking_4b_grpo_test_df_0.csv")
rl_qwen8b
# Out:
#                             concepts  abnormal_stratified  agent_decision  \
# 0                                 []                False        0.035446
# 1                                 []                 True        0.035163
# 2                                 []                False        0.611259
# 3      ['negative_pleural_effusion']                False        0.335722
# 4                                 []                False        0.110497
# ...                              ...                  ...             ...
# 18198                             []                 True        0.347169
# 18199                             []                False        0.048038
# 18200  ['negative_pleural_effusion']                 True        0.776057
# 18201                             []                False        0.102002
# 18202                             []                False        0.014870
#
#                                                 thinking  \
# ...

# %%
rl_qwen8b.loc[rl_qwen8b['reward'] > 0.25, :].to_csv("data_compl_signal/cxr_foundations_w_thinking_4b_grpo_test_df_0_reward_0.25.csv", index=False)
